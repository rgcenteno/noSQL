# %% [markdown]
# # TAREFA: · ACCESO A MONGODB CON PYTHON (PyMongo)
# Colección: `sample_mflix.movies`
#
# ## Exercicio 1. Conexión e exploración
# Conéctate a MongoDB Atlas e accede á base de datos `sample_mflix`
# e á colección `movies`. Amosa un documento completo da colección.

# %%
# Conexión

# %%
# Ex1

# %% [markdown]
# ## Exercicio 2. Consulta básica
# Obtén todas as películas estreadas a partir do ano 2010.

# %%
# Ex2

# %% [markdown]
# ## Exercicio 3. Consulta con filtro composto
# Obtén as películas cunha puntuación IMDb maior ou igual a 8 e cun
# ano de estrea posterior a 2015. Amosa título, ano e puntuación.

# %%
# Ex3

# %% [markdown]
# ## Exercicio 4. Proxección
# Obtén todas as películas do xénero "Drama" mostrando unicamente:
# - título
# - ano
# - duración (runtime)

# %%
# Ex4

# %% [markdown]
# ## Exercicio 5. Ordenación e límite
# Obtén as 10 películas mellor valoradas segundo IMDb.

# %%
# Ex5

# %% [markdown]
# ## Exercicio 6. Actualización de documentos
# Engade un novo campo chamado "clasica" co valor true a todas as
# películas anteriores ao ano 2000.

# %%
# Ex6

# %% [markdown]
# ## Exercicio 7. Eliminación de documentos
# Elimina todas as películas que non teñan puntuación IMDb.

# %%
# Ex7
# Out:
# 61

# %% [markdown]
# ## Exercicio 8. Aggregation Pipeline
# Obtén o número total de películas por ano. Ordena o resultado de
# maior a menor número de películas.

# %%
# Ex8

# %% [markdown]
# ## Exercicio 9. Aggregation con filtro
# Obtén o número de películas do xénero "Comedy" por ano.

# %%
# Ex9

# %% [markdown]
# ## Exercicio 10. Conversión a pandas
# Converte o resultado do exercicio anterior nun DataFrame de pandas
# e renomea o campo _id a "ano".

# %%
# Ex10

# %% [markdown]
# ## Exercicio 11. Análise e visualización
# Representa nunha gráfica de barras os 10 anos con máis películas
# de comedia.

# %%
# Ex11

# %% [markdown]
# ## Exercicio 12. Índices
# Crea un índice no campo `year` e outro índice composto en `year`
# e `genres`. Amosa os índices da colección.

# %%
# Ex12

# %% [markdown]
# ## Exercicio 13. Peche da conexión
# Pecha a conexión con MongoDB.

# %%
# Ex13
